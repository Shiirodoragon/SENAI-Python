# %% [markdown]
# # Desafio
#
# ## Media de Notas
#
# Escreva um programa onde terá o nome do professor, o nome da turma e o nome do aluno. Peça para escrever as 4 notas que foram tiradas e apresente a média final.
#
# 1.   Ignorar espaços no Inicio e no Fim
# 2.   O nome e sobrenome do professor e do aluno tem que estar com a primeira letra em maiusculo
# 3.   O nome da turma tem que ter só a letra do primeiro nome em Maiusculo
# 4.   As notas tem que ser decimais
# 5.   Colocar alerta para utilizar ponto ao invés de virgula

# %% [markdown]
# ## **Teste de Execução 🚀**
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. A nota final de Bruno Santos Almeida, do curso Geografia humana, ministrado por Rafael Souza Lima é 7.0556
# 7. A nota final de Luana Pereira Rodrigues, do curso Química experimental, ministrado por Camila Rodrigues Silva é 3.6999999999999997
# 8. A nota final de Matheus Almeida Martins, do curso Artes visuais, ministrado por Marcelo Oliveira Santos é 6.02
# 9. A nota final de Laura Costa Rocha, do curso Inglês intermediário, ministrado por Juliana Pereira Lima é 6.1925
# 10. A nota final de Tiago Oliveira Silva, do curso Tecnologias da informação e comunicação, ministrado por Gustavo Costa Rocha é 4.612500000000001

# %%
prof = input("Insira o nome do professor  ").title().strip()
aluno = input("Insira o nome do aluno  ").title().strip()
curso = input("Insira o curso  ").capitalize().strip()
print(f"Por favor, insira as notas utilizando o ponto para decimais")
n1 = float(input("Insira a nota 1  "))
n2 = float(input("Insira nota 2  "))
n3 = float(input("Insira nota 3  "))
n4 = float(input("Insira nota 4  "))

resultado = (n1+n2+n3+n4)/4
print(f"A nota final de {aluno}, do curso {curso}, ministrado por {prof} é {resultado:.2f}")


#if(resultado >= 5):
#  print(f"aluno {aluno} foi aprovado")

#else:
# print(f"aluno {aluno} foi reprovado")
# Out:
# Insira o nome do professor  dsbh
# Insira o nome do aluno  dbsj
# Insira o curso  bcxhjv
# Por favor, insira as notas utilizando o ponto para decimais
# Insira a nota 1  4
# Insira nota 2  2
# Insira nota 3  6
# Insira nota 4  7
# A nota final de Dbsj, do curso Bcxhjv, ministrado por Dsbh é 4.75
# 9
